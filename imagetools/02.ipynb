# %%
#Import Lớp Image
from PIL import Image
from imgtools import *

# %%
# Thư mục chứa hình ảnh
dir = 'C:/Users/hieun/Downloads/hinhanh'

# %%
#doc nhieu anh
imgs = get_image_list(dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 #doc nhieu anh
# ----> 2 imgs = get_image_list(dir)
#
# NameError: name 'get_image_list' is not defined

# %%
#hien thi toan bo anh bang ham display
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (880, 587)
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=880x587>
# (900, 507)
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=900x507>
