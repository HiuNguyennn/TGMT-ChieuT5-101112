# %%
# Ctrl + Enter: run code
# Shift + Enter:run code => them mot dong moi

# %%
# Cài đặt
# !pip install Pillow
# !conda install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Pillow in c:\users\hieun\appdata\roaming\python\python312\site-packages (10.4.0)

# %%
# Import thư viện
from PIL import Image

# %%
# Thư mục chứa hình ảnh
dir = 'C:/Users/hieun/Downloads/hinhanh'

# %%
# sử dụng Impage.open() để đọc ảnh
#img01 = Image.open(image_path)

# %%
# đường dẫn đến ảnh
image_path = dir + '/anhdep.jpg.webp'
print(image_path)
# Out:
# C:/Users/hieun/Downloads/hinhanh/anhdep.jpg.webp

# %%
img01 = Image.open(image_path)

# %%
# Hiển thị ảnh
display(img01)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=900x507>

# %%
# In định dạng ảnh
print("Định dạng ảnh: ",img01.format)
# Out:
# Định dạng ảnh:  WEBP

# %%
#In ra kích thước
print("Kích thước hình ảnh: ",img01.size)
# Out:
# Kích thước hình ảnh:  (900, 507)

# %%
#Lưu ảnh và chuyển đổi ảnh
#new_img_01_path  = dir + ' /new_01.JPG'
#img01.save(new_img_01_path)

# %%
# đóng tệp tin
#img_01.close
